# %% [markdown]
# <a href="https://colab.research.google.com/github/ahmed-shiha/NLP_notebooks/blob/main/ar_sent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers[sentencepiece]==4.23.1
# !pip install datasets==2.6.1

# %%
from transformers import pipeline

# %% [markdown]
# #### Sentiment Analysis

# %%
text = "بصراحة لم أعد احب هذا النوع من الأجهزة و أعتقد ان العهد السعيد للشركة سينتهي عما قريب"

# %%
sentiment_pipeline = pipeline('text-classification', 
                              model="nlptown/bert-base-multilingual-uncased-sentiment")

sentiment_pipeline(text)
# Out:
# Downloading:   0%|          | 0.00/953 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/669M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/39.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/872k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# [{'label': '1 star', 'score': 0.39289453625679016}]

# %%
sentiment_pipeline = pipeline('text-classification', 
                              model="CAMeL-Lab/bert-base-arabic-camelbert-da-sentiment")

sentiment_pipeline(text)
# Out:
# Downloading:   0%|          | 0.00/841 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/436M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/86.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/305k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# [{'label': 'positive', 'score': 0.9827591180801392}]

# %%
sentiment_pipeline = pipeline('text-classification', 
                              model="distilbert-base-uncased-finetuned-sst-2-english")

sentiment_pipeline(text)
# Out:
# Downloading:   0%|          | 0.00/629 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/268M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# [{'label': 'NEGATIVE', 'score': 0.6891710758209229}]
